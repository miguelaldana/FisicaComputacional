# %%
# %pylab inlinedata = loadtxt("/home/miguel/Fisica Computacional/solares.txt")
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
u = data[:,0]w = data[:,1]x = data[:,2]y = data[:,3]z = data[:,4]

# %%
n = 2407r = linspace(0,1,n)

# %%
scatter(r,y)

# %%
import matplotlib.pyplot as pltimport numpy as npfrom numpy import pi

# %%
from scipy.fftpack import fft, fftfreqfft_x = fft(y) / n # FFT Normalizedfreq = fftfreq(n, 1) # Recuperamos las frecuenciasplt.plot(freq,np.abs(fft_x),".")

# %%
half_n = np.ceil(n/2.0)fft_x_half = (2.0) * fft_x[:half_n]freq_half = freq[:half_n]plt.plot(freq_half, np.abs(fft_x_half))

# %%
amax = 0.0for i in range(len(fft_x_half)):    if i == 0:        i = 1    if fft_x_half[i] > amax:        amax = fft_x_half[i]        fmax = freq_half[i]Periodo = 1/np.abs(fmax)Periodo
# Out:
# 133.72222222222223
